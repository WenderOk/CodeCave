# %% [markdown]
# # Decimal
# ---

# %%
from decimal import Decimal
d = Decimal(1)
print(d)
print(type(d))
print(d + 5)
print(Decimal(0.1))
print(Decimal("0.1"))
print(Decimal("0.1") + 2)
print(Decimal("0.1") + Decimal("0.1"))

# %%
def multi_div(iterations, number, divisior):
    for _ in range(iterations):
        number /= divisior
    return number

print(decimal_multi_div(3, 56, 2))
print(decimal_multi_div(6, 123456, 10))
print(decimal_multi_div(3, 765432, 10))

def decimal_multi_div(iterations, number, divisior):
    number = Decimal(number)
    for _ in range(iterations):
        number /= divisior
    return number
    
print(decimal_multi_div(3, 56, 2))
print(decimal_multi_div(6, 123456, 10))
print(decimal_multi_div(3, 765432, 10))

# %%
from fractions import Fraction

f1 = Fraction(3, 4)
f2 = Fraction("1/3")
f3 = Fraction("0.25")
f4 = Fraction.from_float(1.5)
print(f1,f2,f3,f4)
print("numerator",f2.numerator)
print("denominator",f2.denominator)

# %%
n = Decimal("311")
d = Decimal("99")
print(n/d)
# Out:
# 3.141414141414141414141414141

# %%
water = Fraction("1/4")
milk = Fraction("1/3")
mash = Fraction("1/2")

r_mash = milk + water - mash
print(r_mash)
# Out:
# 1/4

# %%
money = int(input())
sum1 = Fraction("1/3")*money
sum2 = Fraction("2/5")*money
sum3 = (money - sum1 - sum2) / 2
sum1 += sum3

print(int(sum1))
print(int(sum2))
print(int(sum3))
# Out:
# 300000
# 360000
# 120000
